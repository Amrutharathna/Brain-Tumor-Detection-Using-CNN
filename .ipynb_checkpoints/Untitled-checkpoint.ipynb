# %%
import os
os.listdir("brain_tumor_dataset")
# Out:
# ['no', 'yes']

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
import matplotlib.pyplot as plt

# Path to dataset
data_path = "brain_tumor_dataset"

# Data preprocessing and splitting
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = datagen.flow_from_directory(
    data_path,
    target_size=(64, 64),
    batch_size=16,
    class_mode='binary',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    data_path,
    target_size=(64, 64),
    batch_size=16,
    class_mode='binary',
    subset='validation'
)

# Building CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(64,64,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Compiling model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Training model
history = model.fit(train_gen, validation_data=val_gen, epochs=5)

# Plotting accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.show()

# Saving model
model.save("brain_tumor_detector.h5")

print("✅ Model training completed and saved successfully!")
# Out:
# Found 203 images belonging to 2 classes.
# Found 50 images belonging to 2 classes.
# C:\Users\mr\anaconda3\envs\snscrape_jupyter_env\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\mr\anaconda3\envs\snscrape_jupyter_env\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - accuracy: 0.6749 - loss: 0.5829 - val_accuracy: 0.7600 - val_loss: 0.5360
# ...

# %%
from keras.preprocessing import image
import numpy as np

# ✅ Load the image (your exact file path)
test_image = image.load_img(r"C:\Users\mr\Desktop\BrainTumorProject\archive (9)\yes\Y2.jpg", target_size=(64, 64))

# Convert image to array
img_array = image.img_to_array(test_image)
img_array = np.expand_dims(img_array, axis=0)

# Predict using the trained model
result = model.predict(img_array)

# ✅ Output result
if result[0][0] == 1:
    print("Tumor Detected 🧠⚠️")
else:
    print("No Tumor Detected ✅")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# Tumor Detected 🧠⚠️
